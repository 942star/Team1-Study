# %% [markdown]
# # Version Info

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %load_ext version_information

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %version_information  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# %version_information numpy, pandas
# Out:
# Software versions
# Python 3.6.7 64bit [GCC 8.2.0]
# IPython 7.6.1
# OS Linux 4.4.0 18362 Microsoft x86_64 with Ubuntu 18.04 bionic
# numpy 1.16.4
# pandas 0.25.0
# Tue Jul 23 16:23:19 2019 KST

# %%
# %load_ext watermark

# %%
# %watermark -a 'Watermark' -d -p numpy
# Out:
# Watermark 2019-07-23
#
# numpy 1.16.4

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'

# %%
data = pd.read_csv(url, header=None)

# %%
data
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Pandas data 분석 5총사
# - info
# - describe
# - head
# - tail
# - sample

# %% [markdown]
# ### pd.info
# data에 대한 정보를 보여줌

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# 0    150 non-null float64
# 1    150 non-null float64
# 2    150 non-null float64
# 3    150 non-null float64
# 4    150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### pd.describe
# 각 통계값을 보여줌

# %%
data.describe()
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.describe(include='object')
# Out:
#                   4
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
data.describe(include='all')
# Out:
#                  0           1           2           3            4
# count   150.000000  150.000000  150.000000  150.000000          150
# unique         NaN         NaN         NaN         NaN            3
# top            NaN         NaN         NaN         NaN  Iris-setosa
# freq           NaN         NaN         NaN         NaN           50
# mean      5.843333    3.054000    3.758667    1.198667          NaN
# std       0.828066    0.433594    1.764420    0.763161          NaN
# min       4.300000    2.000000    1.000000    0.100000          NaN
# 25%       5.100000    2.800000    1.600000    0.300000          NaN
# 50%       5.800000    3.000000    4.350000    1.300000          NaN
# 75%       6.400000    3.300000    5.100000    1.800000          NaN
# max       7.900000    4.400000    6.900000    2.500000          NaN

# %%
data.describe(include='float64')
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %%
data.describe(include='number')
# Out:
#                 0           1           2           3
# count  150.000000  150.000000  150.000000  150.000000
# mean     5.843333    3.054000    3.758667    1.198667
# std      0.828066    0.433594    1.764420    0.763161
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.350000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# - 큰 수의 법칙
# - 중심극한 정리

# %%
data.skew()
# Out:
# 0    0.314911
# 1    0.334053
# 2   -0.274464
# 3   -0.104997
# dtype: float64

# %%
data.kurt()
# Out:
# 0   -0.552064
# 1    0.290781
# 2   -1.401921
# 3   -1.339754
# dtype: float64

# %%
data.kurtosis()
# Out:
# 0   -0.552064
# 1    0.290781
# 2   -1.401921
# 3   -1.339754
# dtype: float64

# %% [markdown]
# 정규분포에 가까울수록 데이터 수집이 잘 되었다는 의미

# %% [markdown]
# ## Visualization

# %%
# %matplotlib inline

# %%
data.boxplot()

# %%
import seaborn as sns

# %%
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris, hue='species', markers='+', palette='spring')

# %%
sns.heatmap(iris.corr())

# %% [markdown]
# ---

# %%
tips = sns.load_dataset('tips')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.sample()
# Out:
#      total_bill  tip     sex smoker  day   time  size
# 225       16.27  2.5  Female    Yes  Fri  Lunch     2

# %%
tips.boxplot()

# %%
tips[['total_bill', 'tip']].boxplot()

# %%
tips.groupby('sex').mean()
# Out:
#         total_bill       tip      size
# sex
# Male     20.744076  3.089618  2.630573
# Female   18.056897  2.833448  2.459770

# %%
tips.groupby('sex').sum()
# Out:
#         total_bill     tip  size
# sex
# Male       3256.82  485.07   413
# Female     1570.95  246.51   214

# %%
tips.groupby('sex').max()
# Out:
#         total_bill   tip  size
# sex
# Male         50.81  10.0     6
# Female       44.30   6.5     6

# %%
tips[tips.sex == 'Female'].count()
# Out:
# total_bill    87
# tip           87
# sex           87
# smoker        87
# day           87
# time          87
# size          87
# dtype: int64

# %%
tips[tips.sex == 'Male'].count()
# Out:
# total_bill    157
# tip           157
# sex           157
# smoker        157
# day           157
# time          157
# size          157
# dtype: int64

# %%
tips.groupby(['sex', 'day']).mean()
# Out:
#              total_bill       tip      size
# sex    day
# Male   Thur   18.714667  2.980333  2.433333
#        Fri    19.857000  2.693000  2.100000
#        Sat    20.802542  3.083898  2.644068
#        Sun    21.887241  3.220345  2.810345
# Female Thur   16.715312  2.575625  2.468750
#        Fri    14.145556  2.781111  2.111111
#        Sat    19.680357  2.801786  2.250000
#        Sun    19.872222  3.367222  2.944444

# %%
tips.groupby(['sex', 'day'])['total_bill', 'tip'].mean()
# Out:
#              total_bill       tip
# sex    day
# Male   Thur   18.714667  2.980333
#        Fri    19.857000  2.693000
#        Sat    20.802542  3.083898
#        Sun    21.887241  3.220345
# Female Thur   16.715312  2.575625
#        Fri    14.145556  2.781111
#        Sat    19.680357  2.801786
#        Sun    19.872222  3.367222

# %%
tips.groupby(['sex', 'day', 'time'])['total_bill', 'tip'].mean()
# Out:
#                     total_bill       tip
# sex    day  time
# Male   Thur Lunch    18.714667  2.980333
#             Dinner         NaN       NaN
#        Fri  Lunch    11.386667  1.900000
#             Dinner   23.487143  3.032857
#        Sat  Lunch          NaN       NaN
#             Dinner   20.802542  3.083898
#        Sun  Lunch          NaN       NaN
#             Dinner   21.887241  3.220345
# Female Thur Lunch    16.648710  2.561935
#             Dinner   18.780000  3.000000
#        Fri  Lunch    13.940000  2.745000
#             Dinner   14.310000  2.810000
#        Sat  Lunch          NaN       NaN
#             Dinner   19.680357  2.801786
#        Sun  Lunch          NaN       NaN
#             Dinner   19.872222  3.367222

# %%
mean = tips.groupby('sex')['total_bill', 'tip'].mean()

# %%
mean.plot.bar()

# %%
mean.plot.line()

# %%
mean.plot.barh()

# %% [markdown]
# # 공공데이터

# %%
data = pd.read_csv('data/data.csv', engine='python', encoding='cp949')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
# 연번       81 non-null int64
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 6.5+ KB

# %%
data.describe()
# Out:
#               연번        부지(㎡)       건물(㎡)       회원총계       남자회원       여자회원
# count  81.000000    81.000000   81.000000  81.000000  81.000000  81.000000
# mean   41.000000   169.695556  128.246543  36.234568   8.753086  27.518519
# std    23.526581   157.520518   66.870121  12.110194   8.272743  11.860766
# min     1.000000    18.540000   18.540000  17.000000   0.000000   0.000000
# 25%    21.000000    93.000000   79.000000  27.000000   2.000000  20.000000
# 50%    41.000000   154.110000  126.650000  35.000000   6.000000  26.000000
# 75%    61.000000   201.000000  164.200000  41.000000  13.000000  33.000000
# max    81.000000  1293.300000  374.400000  70.000000  35.000000  67.000000

# %%
data.set_index(['연번'], inplace=True)

# %%
data
# Out:
#           경로당명칭                           소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 2    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 3       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 4        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 5       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 77  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 78  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 79    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 80    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 81      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자
# 연번
# ...

# %% [markdown]
# ---

# %%
data = pd.read_csv('data/data.csv', engine='python', encoding='cp949', index_col='연번')

# %%
data
# Out:
#           경로당명칭                           소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 2    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 3       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 4        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 5       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 77  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 78  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 79    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 80    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 81      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자
# 연번
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81 entries, 1 to 81
# Data columns (total 9 columns):
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 6.3+ KB

# %%
data.describe()
# Out:
#              부지(㎡)       건물(㎡)       회원총계       남자회원       여자회원
# count    81.000000   81.000000  81.000000  81.000000  81.000000
# mean    169.695556  128.246543  36.234568   8.753086  27.518519
# std     157.520518   66.870121  12.110194   8.272743  11.860766
# min      18.540000   18.540000  17.000000   0.000000   0.000000
# 25%      93.000000   79.000000  27.000000   2.000000  20.000000
# 50%     154.110000  126.650000  35.000000   6.000000  26.000000
# 75%     201.000000  164.200000  41.000000  13.000000  33.000000
# max    1293.300000  374.400000  70.000000  35.000000  67.000000

# %%
data = pd.read_csv('data/data.csv', engine='python', encoding='cp949')

# %%
data.set_index(['연번'], inplace=True)

# %%
data
# Out:
#           경로당명칭                           소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 2    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 3       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 4        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 5       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 77  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 78  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 79    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 80    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 81      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자
# 연번
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81 entries, 1 to 81
# Data columns (total 9 columns):
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 6.3+ KB

# %%
data.describe()
# Out:
#              부지(㎡)       건물(㎡)       회원총계       남자회원       여자회원
# count    81.000000   81.000000  81.000000  81.000000  81.000000
# mean    169.695556  128.246543  36.234568   8.753086  27.518519
# std     157.520518   66.870121  12.110194   8.272743  11.860766
# min      18.540000   18.540000  17.000000   0.000000   0.000000
# 25%      93.000000   79.000000  27.000000   2.000000  20.000000
# 50%     154.110000  126.650000  35.000000   6.000000  26.000000
# 75%     201.000000  164.200000  41.000000  13.000000  33.000000
# max    1293.300000  374.400000  70.000000  35.000000  67.000000

# %% [markdown]
# ---

# %%
data = pd.read_csv('data/data.csv', engine='python', encoding='cp949')

# %%
oldRow = data.copy()

# %%
oldRow
# Out:
#     연번        경로당명칭                           소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0    1        내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 1    2   시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 2    3      홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 3    4       황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 4    5      홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..  ..          ...                           ...     ...     ...   ...   ...
# 76  77  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 77  78  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 78  79    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 79  80    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 80  81      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
# ...

# %%
oldRow.set_index('연번', inplace=True)

# %%
oldRow
# Out:
#           경로당명칭                           소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 2    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 3       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 4        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 5       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 77  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 78  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 79    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 80    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 81      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자
# 연번
# ...

# %%
oldRow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81 entries, 1 to 81
# Data columns (total 9 columns):
# 경로당명칭    81 non-null object
# 소재지      81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 6.3+ KB

# %%
oldRow.reset_index()
# Out:
#     연번        경로당명칭                           소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0    1        내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 1    2   시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 2    3      홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 3    4       황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 4    5      홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..  ..          ...                           ...     ...     ...   ...   ...
# 76  77  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 77  78  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 78  79    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 79  80    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 80  81      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
# ...

# %%
oldRow.reset_index(drop=True)
# Out:
#           경로당명칭                           소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 1    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 2       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 3        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 4       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 76  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 77  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 78    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 79    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 80      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자
# 0     40  053-554-0739  2017-11-10
# ...

# %%
oldRow.reset_index(drop=True, inplace=True)

# %%
oldRow
# Out:
#           경로당명칭                           소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 1    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 2       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 3        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 4       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 76  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 77  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 78    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 79    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 80      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자
# 0     40  053-554-0739  2017-11-10
# ...

# %% [markdown]
# ---

# %%
oldRow = data.copy()

# %%
oldRow.set_index('연번', inplace=True)

# %%
oldRow.drop(labels=[1,3,4])
# Out:
#           경로당명칭                         소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  여자회원  \
# 연번
# 2    시영내당(아)경로당  대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6    18
# 5       홍실2차경로당    대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0    31
# 6         장수경로당          대구광역시 서구 큰장로9길 9-3  159.00  112.00    38     5    33
# 7       내당2동경로당       대구광역시 서구 큰장로15길 14-20   93.00   62.64    35    10    25
# 8         내당경로당         대구광역시 서구 평리로 408-13  216.00  183.68    40     5    35
# ..          ...                         ...     ...     ...   ...   ...   ...
# 77  원대1,2가제1경로당         대구광역시 서구 달서천로 405-3  200.28  224.80    35    35     0
# 78  원대1,2가제2경로당       대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0    67
# 79    원대3가제1경로당           대구광역시 서구 고성로21길 6  262.00  122.85    30     7    23
# 80    원대3가제2경로당         대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10    30
# 81      금류타운경로당    대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8    19
#
# ...

# %%
oldRow.drop(labels='소재지', axis=1)
# Out:
#           경로당명칭   부지(㎡)   건물(㎡)  회원총계  남자회원  여자회원          전화번호        기준일자
# 연번
# 1         내서경로당  139.80  160.80    40     0    40  053-554-0739  2017-11-10
# 2    시영내당(아)경로당  119.00  119.00    24     6    18  053-567-9772  2017-11-10
# 3       홍실1차경로당   90.00   90.00    41     9    32  053-551-8286  2017-11-10
# 4        황성정경로당  134.74  134.74    40    10    30  053-553-9874  2017-11-10
# 5       홍실2차경로당  154.11  154.11    31     0    31  053-556-8220  2017-11-10
# ..          ...     ...     ...   ...   ...   ...           ...         ...
# 77  원대1,2가제1경로당  200.28  224.80    35    35     0  053-354-8695  2017-11-10
# 78  원대1,2가제2경로당  285.90  374.40    67     0    67  053-357-8561  2017-11-10
# 79    원대3가제1경로당  262.00  122.85    30     7    23  053-354-7665  2017-11-10
# 80    원대3가제2경로당  238.00  263.00    40    10    30  053-355-1577  2017-11-10
# 81      금류타운경로당   84.39   84.39    27     8    19  053-359-1769  2017-11-10
#
# [81 rows x 8 columns]
# ...

# %%
oldRow
# Out:
#           경로당명칭                           소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 연번
# 1         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 2    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 3       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 4        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 5       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 77  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 78  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 79    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 80    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 81      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자
# 연번
# ...

# %%
oldRow = data.copy()

# %%
oldRow.drop(labels='연번', axis=1, inplace=True)

# %%
oldRow
# Out:
#           경로당명칭                           소재지   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 1    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 2       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 3        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 4       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 76  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 77  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 78    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 79    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 80      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자
# 0     40  053-554-0739  2017-11-10
# ...

# %%
oldRow.rename({'소재지':'주소'}, axis=1, inplace=True)

# %%
oldRow
# Out:
#           경로당명칭                            주소   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 1    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 2       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 3        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 4       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 76  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 77  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 78    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 79    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 80      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자
# 0     40  053-554-0739  2017-11-10
# ...

# %%
oldRow['시'] = oldRow['주소']

# %%
oldRow
# Out:
#           경로당명칭                            주소   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 1    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 2       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 3        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 4       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 76  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 77  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 78    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 79    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 80      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자                             시
# ...

# %%
oldRow['시'] = '대구광역시'

# %%
oldRow
# Out:
#           경로당명칭                            주소   부지(㎡)   건물(㎡)  회원총계  남자회원  \
# 0         내서경로당      대구광역시 서구 달구벌대로361길 35-29  139.80  160.80    40     0
# 1    시영내당(아)경로당    대구광역시 서구 서대구로8길 15 내당시영아파트  119.00  119.00    24     6
# 2       홍실1차경로당  대구광역시 서구 서대구로8길 49 내당보성홍실아파트   90.00   90.00    41     9
# 3        황성정경로당               대구광역시 서구 통학로 46  134.74  134.74    40    10
# 4       홍실2차경로당      대구광역시 서구 통학로 39 보성2차홍실타운  154.11  154.11    31     0
# ..          ...                           ...     ...     ...   ...   ...
# 76  원대1,2가제1경로당           대구광역시 서구 달서천로 405-3  200.28  224.80    35    35
# 77  원대1,2가제2경로당         대구광역시 서구 달서천로86길 6-10  285.90  374.40    67     0
# 78    원대3가제1경로당             대구광역시 서구 고성로21길 6  262.00  122.85    30     7
# 79    원대3가제2경로당           대구광역시 서구 팔달로46길 4-2  238.00  263.00    40    10
# 80      금류타운경로당      대구광역시 서구 원대로13길 2 원대금류타운   84.39   84.39    27     8
#
#     여자회원          전화번호        기준일자      시
# ...

# %%
oldRow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
# 경로당명칭    81 non-null object
# 주소       81 non-null object
# 부지(㎡)    81 non-null float64
# 건물(㎡)    81 non-null float64
# 회원총계     81 non-null int64
# 남자회원     81 non-null int64
# 여자회원     81 non-null int64
# 전화번호     81 non-null object
# 기준일자     81 non-null object
# 시        81 non-null object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 6.5+ KB

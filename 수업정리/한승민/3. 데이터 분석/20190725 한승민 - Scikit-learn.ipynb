# %% [markdown]
# # Scikit-learn
# ## load dataset
# - make: dataset 생성
# - fetch: web에서부터 dataset download
# - load: scikit-learn에서 기본적으로 제공해주는 tidy-data

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
import pandas as pd

# %%
data = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
target = pd.DataFrame(iris.target, columns=['target'])

# %%
dataset = pd.concat([data, target], axis=1)

# %%
dataset
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %% [markdown]
# # Model Selection
# 최적의 모델을 사용하기 위한 기법

# %%
from sklearn.model_selection import train_test_split

# %%
X = dataset.iloc[:, :-1]
y = dataset[['target']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# /home/hsm/.venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
knn.score(X_test, y_test)
# Out:
# 0.9473684210526315

# %%
vars(knn)
# Out:
# {'n_neighbors': 5,
#  'radius': None,
#  'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'p': 2,
#  'n_jobs': None,
#  'weights': 'uniform',
#  'outputs_2d_': False,
#  'classes_': array([0, 1, 2]),
#  '_y': array([1, 0, 0, 2, 0, 2, 2, 2, 1, 1, 0, 2, 1, 1, 2, 2, 0, 2, 1, 0, 2, 2,
#         2, 0, 2, 0, 0, 1, 0, 0, 1, 2, 0, 1, 2, 0, 1, 1, 0, 2, 2, 2, 0, 0,
#         1, 1, 2, 2, 0, 2, 1, 1, 1, 1, 1, 0, 0, 2, 0, 0, 1, 1, 1, 1, 2, 2,
#         0, 2, 0, 2, 1, 1, 2, 1, 0, 2, 0, 2, 0, 2, 0, 0, 1, 1, 1, 1, 1, 1,
#         0, 2, 0, 0, 2, 0, 0, 1, 1, 2, 2, 0, 2, 1, 2, 0, 2, 0, 2, 1, 2, 1,
#         0, 1]),
#  'effective_metric_params_': {},
#  'effective_metric_': 'euclidean',
#  '_fit_method': 'kd_tree',
#  '_fit_X': array([[5.5, 2.4, 3.8, 1.1],
#         [5.5, 4.2, 1.4, 0.2],
#         [5.7, 4.4, 1.5, 0.4],
#         [7.2, 3.2, 6. , 1.8],
#         [4.9, 3.1, 1.5, 0.2],
#         [6.3, 2.8, 5.1, 1.5],
#         [6.7, 3.1, 5.6, 2.4],
#         [6.1, 3. , 4.9, 1.8],
#         [6.3, 2.3, 4.4, 1.3],
#         [5.6, 3. , 4.5, 1.5],
#         [5.2, 4.1, 1.5, 0.1],
#         [7.7, 2.6, 6.9, 2.3],
#         [5.6, 3. , 4.1, 1.3],
#         [5.7, 2.8, 4.5, 1.3],
#         [6.5, 3. , 5.8, 2.2],
#         [5.6, 2.8, 4.9, 2. ],
#         [4.8, 3. , 1.4, 0.3],
#         [6.5, 3. , 5.2, 2. ],
#         [6.1, 3. , 4.6, 1.4],
#         [5.8, 4. , 1.2, 0.2],
#         [5.9, 3. , 5.1, 1.8],
#         [6.9, 3.2, 5.7, 2.3],
#         [6.9, 3.1, 5.4, 2.1],
#         [5.4, 3.4, 1.7, 0.2],
#         [6. , 2.2, 5. , 1.5],
#         [5.7, 3.8, 1.7, 0.3],
#         [5. , 3. , 1.6, 0.2],
#         [5.7, 2.6, 3.5, 1. ],
#         [5.4, 3.9, 1.3, 0.4],
#         [4.6, 3.6, 1. , 0.2],
#         [5.6, 2.5, 3.9, 1.1],
#         [6.1, 2.6, 5.6, 1.4],
#         [5. , 3.5, 1.6, 0.6],
#         [5.7, 2.9, 4.2, 1.3],
#         [6.7, 3.3, 5.7, 2.5],
#         [5.4, 3.4, 1.5, 0.4],
#         [6.7, 3.1, 4.7, 1.5],
#         [6.6, 2.9, 4.6, 1.3],
#         [4.7, 3.2, 1.3, 0.2],
#         [6.8, 3.2, 5.9, 2.3],
#         [7.6, 3. , 6.6, 2.1],
#         [7.4, 2.8, 6.1, 1.9],
#         [4.4, 2.9, 1.4, 0.2],
#         [5.1, 3.8, 1.9, 0.4],
#         [6.5, 2.8, 4.6, 1.5],
#         [6.7, 3.1, 4.4, 1.4],
#         [7.7, 2.8, 6.7, 2. ],
#         [7.9, 3.8, 6.4, 2. ],
#         [4.7, 3.2, 1.6, 0.2],
#         [6.2, 2.8, 4.8, 1.8],
#         [6.7, 3. , 5. , 1.7],
#         [6.8, 2.8, 4.8, 1.4],
#         [5.5, 2.5, 4. , 1.3],
#         [5.5, 2.6, 4.4, 1.2],
#         [5.5, 2.4, 3.7, 1. ],
#         [4.6, 3.1, 1.5, 0.2],
#         [4.5, 2.3, 1.3, 0.3],
#         [7.1, 3. , 5.9, 2.1],
#         [4.8, 3.4, 1.6, 0.2],
#         [4.9, 3. , 1.4, 0.2],
#         [6.2, 2.2, 4.5, 1.5],
#         [5.8, 2.6, 4. , 1.2],
#         [6.4, 2.9, 4.3, 1.3],
#         [5.6, 2.7, 4.2, 1.3],
#         [5.8, 2.7, 5.1, 1.9],
#         [7.2, 3.6, 6.1, 2.5],
#         [5.2, 3.4, 1.4, 0.2],
#         [5.7, 2.5, 5. , 2. ],
#         [5.1, 3.7, 1.5, 0.4],
#         [7.3, 2.9, 6.3, 1.8],
#         [5.7, 2.8, 4.1, 1.3],
#         [5.1, 2.5, 3. , 1.1],
#         [6.3, 3.3, 6. , 2.5],
#         [6. , 3.4, 4.5, 1.6],
#         [5.1, 3.5, 1.4, 0.2],
#         [6.4, 3.1, 5.5, 1.8],
#         [5. , 3.3, 1.4, 0.2],
#         [7.2, 3. , 5.8, 1.6],
#         [5.4, 3.9, 1.7, 0.4],
#         [6.4, 3.2, 5.3, 2.3],
#         [4.9, 3.1, 1.5, 0.1],
#         [5. , 3.4, 1.6, 0.4],
#         [5. , 2. , 3.5, 1. ],
#         [6.1, 2.9, 4.7, 1.4],
#         [5.8, 2.7, 3.9, 1.2],
#         [7. , 3.2, 4.7, 1.4],
#         [5.9, 3.2, 4.8, 1.8],
#         [5.9, 3. , 4.2, 1.5],
#         [5. , 3.6, 1.4, 0.2],
#         [6.5, 3. , 5.5, 1.8],
#         [4.4, 3.2, 1.3, 0.2],
#         [5.5, 3.5, 1.3, 0.2],
#         [6.4, 2.8, 5.6, 2.2],
#         [4.8, 3. , 1.4, 0.1],
#         [4.3, 3. , 1.1, 0.1],
#         [6.3, 2.5, 4.9, 1.5],
#         [6.3, 3.3, 4.7, 1.6],
#         [6. , 3. , 4.8, 1.8],
#         [7.7, 3.8, 6.7, 2.2],
#         [5.1, 3.8, 1.6, 0.2],
#         [6.7, 3.3, 5.7, 2.1],
#         [6. , 2.2, 4. , 1. ],
#         [6.8, 3. , 5.5, 2.1],
#         [5.1, 3.4, 1.5, 0.2],
#         [6.2, 3.4, 5.4, 2.3],
#         [5.2, 3.5, 1.5, 0.2],
#         [6.3, 2.5, 5. , 1.9],
#         [6.1, 2.8, 4. , 1.3],
#         [6.9, 3.1, 5.1, 2.3],
#         [5.5, 2.3, 4. , 1.3],
#         [4.9, 3.6, 1.4, 0.1],
#         [6. , 2.9, 4.5, 1.5]]),
#  '_tree': <sklearn.neighbors.kd_tree.KDTree at 0x33223f8>}

# %%
knn.fit(dataset.iloc[:, :-1], dataset[dataset.columns[-1]])
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')
